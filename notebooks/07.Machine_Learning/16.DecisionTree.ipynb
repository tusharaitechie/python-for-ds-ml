# %% [markdown]
# ### Decision Tree (Classification)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

dataset = pd.read_excel("../../datasets/Social_Network_Ads.xlsx")
dataset.head(5)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   22            25000          0
# 1   25            27000          0
# 2   30            30000          0
# 3   35            32000          1
# 4   40            35000          1

# %%
sns.scatterplot(x="Age", y = "EstimatedSalary", data=dataset, hue="Purchased")
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x = dataset.iloc[:, :-1]
y = dataset["Purchased"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc =  StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x), columns=x.columns)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(x_test, y_test)*100
# Out:
# 100.0

# %%
dt.predict([[ 22, 25000]])
# Out:
# c:\Users\Tushar Nile\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
dt.predict([[40, 35000]])
# Out:
# c:\Users\Tushar Nile\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=dt)
plt.show()
# Out:
# c:\Users\Tushar Nile\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20,20))
plot_tree(dt)
plt.show()

# %% [markdown]
# we will try with other values

# %%
dt1 = DecisionTreeClassifier(criterion="entropy") # 'gini', 'entropy', 'log_loss' , default ='gini'
dt1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt1.score(x_test, y_test)*100
# Out:
# 100.0

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=dt1)
plt.show()
# Out:
# c:\Users\Tushar Nile\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
