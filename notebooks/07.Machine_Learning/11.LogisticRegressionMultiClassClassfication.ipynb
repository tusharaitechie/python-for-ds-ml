# %% [markdown]
# ### Logistic Regression - Multiclass Classification

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataset = pd.read_excel("../../datasets/iris.xlsx")

dataset.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.1          3.5           1.4          0.2      setosa
# 1           4.9          3.0           1.4          0.2      setosa
# 2           5.8          2.7           5.1          1.9   virginica
# 3           6.0          2.2           5.0          1.5   virginica
# 4           5.7          2.8           4.1          1.3  versicolor

# %%
dataset["species"].unique()
# Out:
# <StringArray>
# ['setosa', 'virginica', 'versicolor']
# Length: 3, dtype: str

# %% [markdown]
# inke under kya relationship hai dekhne ke liye hum pairplot ka use karenge

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.pairplot(data=dataset, hue="species")
plt.show()

# %%
x = dataset.iloc[:, : -1]
y = dataset["species"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Hindi (देवनागरी):
# नया scikit-learn खुद ही decide करता है कि OVR या multinomial क्या use करना है। ज़्यादातर cases में result same या better आता है।
#
# English:
# The newer version of scikit-learn automatically chooses the best strategy. Results will usually be the same or even better.(If you use new version , in old version you can use OVR and Multinomial , but nowdays it is depricated , better to avoid )

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)
# Out:
# 1.0
