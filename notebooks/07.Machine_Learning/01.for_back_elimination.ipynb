# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector 

dataset = pd.read_excel("../../datasets/diabetes.xlsx")

dataset.head(5)
# Out:
#    Glucose  BloodPressure  SkinThickness   BMI  Age  Outcome
# 0       85             66             29  26.6   31        0
# 1       89             70             23  28.1   25        0
# 2       95             72             35  32.0   33        1
# 3      105             75             30  34.2   45        1
# 4      110             80             25  36.5   50        1

# %%
x = dataset.iloc[:, : -1]

# %%
y = dataset["Outcome"]

# %%
x.shape
# Out:
# (15, 5)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
k_features = 5

# %%
fs = SequentialFeatureSelector(lr, k_features, forward = True)

# %%
fs.fit(x, y)
# Out:
# c:\Users\Tushar Nile\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\externals\_numpydoc\docscrape.py:203: UserWarning: potentially wrong underline length...
# Examples
# ----------- in
# Sequential Feature Selection for Classification and Regression.
# ...
#   while not self._is_at_section() and not self._doc.eof():
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(5, 5),
#                           scoring='accuracy')

# %%
fs.feature_names
# Out:
# ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age']

# %%
fs.k_feature_names_
# Out:
# ('Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'Age')

# %%
fs.k_score_
# Out:
# np.float64(0.9333333333333332)
