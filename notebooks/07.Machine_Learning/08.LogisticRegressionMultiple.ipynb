# %% [markdown]
# ### Logistic Regression Multiple Input

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("../../datasets/placement.xlsx")
dataset.head(5)
# Out:
#    CGPA  Score  Placed
# 0   6.2     55       0
# 1   6.5     60       0
# 2   7.0     65       0
# 3   7.5     70       1
# 4   8.0     75       1

# %%
sns.scatterplot(x="CGPA", y = "Score", data=dataset, hue="Placed")
plt.legend(loc=1)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset["Placed"]
x
x.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 100.0

# %%
lr.predict([[7.0, 65]])
# Out:
# c:\Users\Tushar Nile\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
lr.coef_
# Out:
# array([[0.0999825 , 0.98934217]])

# %%
lr.intercept_
# Out:
# array([-67.13500793])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=lr)
plt.show()
# Out:
# c:\Users\Tushar Nile\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
