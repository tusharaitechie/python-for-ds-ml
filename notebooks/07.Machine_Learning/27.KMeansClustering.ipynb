# %% [markdown]
# k-Means tabhi use karna hai jab data linear ho otherwise other algo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_excel("../../datasets/iris row.xlsx")

dataset.head(5)
# Out:
#    Sepal_Length   Sepal_Width   Petal_Length  Petal_Width
# 0            5.1           3.5           1.4           0.2
# 1            4.9           3.0           1.4           0.2
# 2            5.8           2.7           5.1           1.9
# 3            6.0           2.2           4.0           1.0
# 4            5.5           2.3           4.0           1.3

# %%
sns.pairplot(data=dataset)
plt.show()

# %% [markdown]
# unlabeled data ko split nahi karte

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(2, 21):
    km = KMeans(n_clusters=i, init='k-means++')
    km.fit(dataset)
    wcss.append(km.inertia_)

# %%
plt.figure(figsize=(10,5))
plt.plot([i for i in range(2, 21)], wcss, marker="o")
plt.xlabel("no of cluster")
plt.xticks([i for i in range(2, 21)])
plt.ylabel("WCSS")
plt.grid(axis="x")
plt.show()

# %%
kmn = KMeans(n_clusters=3)
dataset["Predict"] = kmn.fit_predict(dataset)

# %%
dataset
# Out:
#     Sepal_Length   Sepal_Width   Petal_Length  Petal_Width   Predict
# 0             5.1           3.5           1.4           0.2        1
# 1             4.9           3.0           1.4           0.2        1
# 2             5.8           2.7           5.1           1.9        2
# 3             6.0           2.2           4.0           1.0        0
# 4             5.5           2.3           4.0           1.3        0
# 5             6.3           3.3           6.0           2.5        2
# 6             5.7           2.8           4.5           1.3        0
# 7             6.7           3.1           4.7           1.5        2
# 8             5.0           3.4           1.5           0.2        1
# 9             6.4           2.9           4.3           1.3        0
# 10            4.6           3.2           1.4           0.2        1
# 11            5.2           2.7           3.9           1.4        0
# 12            6.9           3.1           5.4           2.1        2
# 13            5.4           3.9           1.7           0.4        1
# 14            6.1           2.8           4.7           1.2        0
# 15            5.6           2.9           3.6           1.3        0
# 16            6.5           3.0           5.8           2.2        2
# 17            5.0           3.5           1.6           0.6        1
# 18            6.2           2.8           4.8           1.8        2
# 19            5.9           3.0           5.1           1.8        2

# %%
sns.pairplot(data=dataset, hue="Predict")
plt.show()

# %%
org_dataset =  pd.read_excel("D:\Practice\JupitorNoteBookPrograms\datasets\iris.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_29868\3160421319.py:1: SyntaxWarning: invalid escape sequence '\P'
#   org_dataset =  pd.read_excel("D:\Practice\JupitorNoteBookPrograms\datasets\iris.xlsx")

# %%
sns.pairplot(data=org_dataset, hue="species")
plt.show()
