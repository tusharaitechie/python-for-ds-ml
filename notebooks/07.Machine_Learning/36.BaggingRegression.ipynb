# %% [markdown]
# Regression Technique

# %%
import pandas as pd

dataset =  pd.read_csv("../../datasets/placement.csv")

dataset.head(5)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x = dataset.iloc[:,:-1]
y = dataset["package"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
bg = BaggingRegressor(estimator=LinearRegression(), n_estimators=40)
bg.fit(x_train, y_train)
bg.score(x_train, y_train)*100, bg.score(x_test, y_test)*100
# Out:
# (77.58137649523012, 77.39281169481369)

# %%
rf = RandomForestRegressor(n_estimators=50)
rf.fit(x_train, y_train)
rf.score(x_train, y_train)*100, rf.score(x_test, y_test)*100
# Out:
# (91.75832174474692, 66.68659819507556)
