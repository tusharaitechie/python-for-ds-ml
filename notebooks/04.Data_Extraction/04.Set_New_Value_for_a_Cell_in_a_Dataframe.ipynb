# %%
import pandas as pd

# read csv file
df = pd.read_csv('../../datasets/players_20.csv', encoding='latin1')

# set index
df.set_index('short_name', inplace=True)

# select column
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %%
# show dataframe
df.head(5)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia     AtlÃ©tico Madrid
# E. Hazard                175         74     Belgium          Real Madrid

# %% [markdown]
# ### Set value to one cell

# %%
# update L. Messi height
df.loc['L. Messi', 'height_cm'] = 175

# %%
# show dataframe
df.head(5)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 175         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia     AtlÃ©tico Madrid
# E. Hazard                175         74     Belgium          Real Madrid

# %% [markdown]
# ### Set value to entire column

# %%
# set height of all players to 190
df.loc[:, 'height_cm'] = 190

# %%
# show dataframe
df.head(5)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 190         72   Argentina         FC Barcelona
# Cristiano Ronaldo        190         83    Portugal             Juventus
# Neymar Jr                190         68      Brazil  Paris Saint-Germain
# J. Oblak                 190         87    Slovenia     AtlÃ©tico Madrid
# E. Hazard                190         74     Belgium          Real Madrid

# %% [markdown]
# ### Set value to entire row

# %%
# get all columns that correspond to player ranked last in fifa
df.iloc[-1,:]
# Out:
# long_name                   æ½åæ
# age                                26
# dob                        1993-01-11
# height_cm                         190
# weight_kg                          78
# nationality                  China PR
# club           Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
# set null values to all columns that corresponds to  player ranked last in fifa
import numpy as np
df.iloc[-1, :] = np.nan

# %%
# show dataframe
df.head(5)
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi               190.0       72.0   Argentina         FC Barcelona
# Cristiano Ronaldo      190.0       83.0    Portugal             Juventus
# Neymar Jr              190.0       68.0      Brazil  Paris Saint-Germain
# J. Oblak               190.0       87.0    Slovenia     AtlÃ©tico Madrid
# E. Hazard              190.0       74.0     Belgium          Real Madrid

# %% [markdown]
# ### Set value to Multiple cells

# %%
# Set value for all items matching the list of labels
df.loc[['L. Messi', 'Cristiano Ronaldo'], ['height_cm']] = 175

# %%
# show dataframe
df.head(5)
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi               175.0       72.0   Argentina         FC Barcelona
# Cristiano Ronaldo      175.0       83.0    Portugal             Juventus
# Neymar Jr              190.0       68.0      Brazil  Paris Saint-Germain
# J. Oblak               190.0       87.0    Slovenia     AtlÃ©tico Madrid
# E. Hazard              190.0       74.0     Belgium          Real Madrid

# %% [markdown]
# ### Set value for rows matching a condition

# %%
# set value for rows matching a condition
columns = ['age', 'dob', 'height_cm', 'weight_kg']

df.loc[df['height_cm']>180, columns] = 0

# %%
# show dataframe
df.head(5)
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   0.0           0
# J. Oblak                                     Jan Oblak   0.0           0
# E. Hazard                                  Eden Hazard   0.0           0
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi               175.0       72.0   Argentina         FC Barcelona
# Cristiano Ronaldo      175.0       83.0    Portugal             Juventus
# Neymar Jr                0.0        0.0      Brazil  Paris Saint-Germain
# J. Oblak                 0.0        0.0    Slovenia     AtlÃ©tico Madrid
# E. Hazard                0.0        0.0     Belgium          Real Madrid
