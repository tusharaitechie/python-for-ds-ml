# %% [markdown]
# ### Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10, 60, (50))
print(x)
# Out:
# [20 24 58 46 38 28 19 39 28 43 10 55 38 25 59 48 32 56 54 48 53 15 12 10
#  48 34 45 26 35 50 15 46 24 26 39 34 12 43 14 10 25 50 14 39 35 49 26 58
#  13 19]

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

plt.hist(no)
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

plt.hist(no)

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

plt.hist(no, color="r")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

plt.hist(no, color="b", edgecolor="r")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

plt.hist(no, "auto", (0, 200), edgecolor="r")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_6580\4231536967.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(no, "auto", (0, 200), edgecolor="r")

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

plt.hist(no, "auto", (0, 200), edgecolor="r", cumulative=-1) # cumulative property keeps reverse order

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_6580\574855301.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(no, "auto", (0, 200), edgecolor="r", cumulative=-1) # cumulative property keeps reverse order

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", edgecolor="r", bottom=20)

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", align="left")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", align="mid")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", histtype="step")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", histtype="stepfilled")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", histtype="barstacked")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", histtype="bar")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", orientation="horizontal")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", orientation="vertical")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", rwidth=0.8)

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", log=True)

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", label="python")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", label="python")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")
plt.legend()
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", label="python")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")

plt.axvline(45, color="r")

plt.legend()
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", label="python")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")

plt.axvline(45, color="g", label="line")

plt.legend()
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="m", bins=l, edgecolor="r", label="python")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")

plt.axvline(45, color="g", label="line")

plt.legend()
plt.show()

# %%
no=[32, 59, 10, 39, 14, 41, 11, 28, 30, 54, 56, 14, 22, 37, 19, 55, 10, 44, 30, 47, 44, 20, 12, 22,
 23, 47, 55, 37, 17, 50, 32, 49, 30, 21, 33, 18, 19, 12, 16, 19, 29, 11, 40, 40, 29, 15, 30, 15,
 35, 28]

l = [10, 20, 30, 40, 50, 60]
plt.hist(no, color="b", bins=l, edgecolor="r", label="python")

plt.title("Exercise")
plt.xlabel("python")
plt.ylabel("No.")

plt.axvline(45, color="g", label="line")

plt.legend()
plt.grid()
plt.show()
