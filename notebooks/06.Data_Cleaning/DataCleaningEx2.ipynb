# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataset = pd.read_csv("../../datasets/loan_dataset.csv", encoding='latin1')

dataset.head(5)
# Out:
#   Loan_ID  Gender Married Dependend Education Self_Employment  Application  \
# 0  LP1001     NaN      No        3+  Graduate             Yes      5745.07
# 1  LP1002    Male     Yes        3+  Not Grad             Yes      7284.54
# 2  LP1003  Female     Yes         1  Not Grad              No      7368.82
# 3  LP1004     NaN     Yes         1  Not Grad             NaN      5813.84
# 4  LP1005  Female     Yes       NaN  Not Grad             NaN      5362.94
#
#    Coapplication  LoanAmount  Credit_History Property_Area Loan_status
# 0        1889.39      155.91             NaN         Rural           N
# 1        1812.68      120.63             NaN     Semiurban           Y
# 2        2613.95      111.22             0.0         Urban           Y
# 3        1629.27      111.37             0.0         Urban           Y
# 4         469.38       61.00             0.0         Rural           N

# %%
dataset.shape
# Out:
# (1050, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Loan_ID          1050 non-null   object
#  1   Gender           676 non-null    object
#  2   Married          728 non-null    object
#  3   Dependend        855 non-null    object
#  4   Education        1050 non-null   object
#  5   Self_Employment  704 non-null    object
#  6   Application      1050 non-null   float64
#  7   Coapplication    1050 non-null   float64
#  8   LoanAmount       1050 non-null   float64
#  9   Credit_History   683 non-null    float64
#  10  Property_Area    1050 non-null   object
#  11  Loan_status      1050 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 98.6+ KB

# %%
dataset.isnull()
# Out:
#       Loan_ID  Gender  Married  Dependend  Education  Self_Employment  \
# 0       False    True    False      False      False            False
# 1       False   False    False      False      False            False
# 2       False   False    False      False      False            False
# 3       False    True    False      False      False             True
# 4       False   False    False       True      False             True
# ...       ...     ...      ...        ...        ...              ...
# 1045    False   False     True      False      False            False
# 1046    False   False    False      False      False            False
# 1047    False    True     True      False      False            False
# 1048    False   False    False      False      False             True
# 1049    False    True    False      False      False             True
#
#       Application  Coapplication  LoanAmount  Credit_History  Property_Area  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender             374
# Married            322
# Dependend          195
# Education            0
# Self_Employment    346
# Application          0
# Coapplication        0
# LoanAmount           0
# Credit_History     367
# Property_Area        0
# Loan_status          0
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(1604)

# %%
dataset.shape[0]
# Out:
# 1050

# %%
dataset.shape[1]
# Out:
# 12

# %%
(dataset.isnull().sum()/dataset.shape[0]) * 100
# Out:
# Loan_ID             0.000000
# Gender             35.619048
# Married            30.666667
# Dependend          18.571429
# Education           0.000000
# Self_Employment    32.952381
# Application         0.000000
# Coapplication       0.000000
# LoanAmount          0.000000
# Credit_History     34.952381
# Property_Area       0.000000
# Loan_status         0.000000
# dtype: float64

# %%
(dataset.isnull().sum()/dataset.shape[0]*dataset.shape[1])*100
# Out:
# Loan_ID              0.000000
# Gender             427.428571
# Married            368.000000
# Dependend          222.857143
# Education            0.000000
# Self_Employment    395.428571
# Application          0.000000
# Coapplication        0.000000
# LoanAmount           0.000000
# Credit_History     419.428571
# Property_Area        0.000000
# Loan_status          0.000000
# dtype: float64

# %%
dataset.notnull().sum()
# Out:
# Loan_ID            1050
# Gender              676
# Married             728
# Dependend           855
# Education          1050
# Self_Employment     704
# Application        1050
# Coapplication      1050
# LoanAmount         1050
# Credit_History      683
# Property_Area      1050
# Loan_status        1050
# dtype: int64

# %%
dataset.notnull().sum().sum()
# Out:
# np.int64(10996)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=["Credit_History"], inplace=True) # removes the Credit_History column

# %%
dataset.dropna(inplace=True) # removes all the rows which has null value present

# %%
dataset.isnull().sum()
# Out:
# Loan_ID            0
# Gender             0
# Married            0
# Dependend          0
# Education          0
# Self_Employment    0
# Application        0
# Coapplication      0
# LoanAmount         0
# Property_Area      0
# Loan_status        0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.shape
# Out:
# (256, 11)

# %%
dataset.dropna(axis=1, inplace=True) # remove all the columns which has null value present
