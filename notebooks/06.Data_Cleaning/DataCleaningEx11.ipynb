# %% [markdown]
# ### One Hot Encoding using Scikit learn

# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Aman", "Sita", "Neha"],
    "Gender": ["Male", "Male", "Female", "Female"],
    "Age": [23, 25, 22, 24]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Gender  Age
# 0  Rahul    Male   23
# 1   Aman    Male   25
# 2   Sita  Female   22
# 3   Neha  Female   24

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()

encoded = encoder.fit_transform(df[["Gender"]]).toarray()
encoded
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [1., 0.],
#        [1., 0.]])

# %%
columns = encoder.get_feature_names_out(["Gender"])
columns
# Out:
# array(['Gender_Female', 'Gender_Male'], dtype=object)

# %%
encoded_df = pd.DataFrame(encoded, columns=columns)
encoded_df
# Out:
#    Gender_Female  Gender_Male
# 0            0.0          1.0
# 1            0.0          1.0
# 2            1.0          0.0
# 3            1.0          0.0

# %%
df = pd.concat([df, encoded_df], axis=1)
df
# Out:
#     Name  Gender  Age  Gender_Female  Gender_Male
# 0  Rahul    Male   23            0.0          1.0
# 1   Aman    Male   25            0.0          1.0
# 2   Sita  Female   22            1.0          0.0
# 3   Neha  Female   24            1.0          0.0

# %%
df = df.drop("Gender", axis=1)
df
# Out:
#     Name  Age  Gender_Female  Gender_Male
# 0  Rahul   23            0.0          1.0
# 1   Aman   25            0.0          1.0
# 2   Sita   22            1.0          0.0
# 3   Neha   24            1.0          0.0

# %%
'''
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

encoder = OneHotEncoder(sparse_output=False)

encoded = encoder.fit_transform(df[["Gender"]])

encoded_df = pd.DataFrame(encoded, columns=encoder.get_feature_names_out(["Gender"]))

df = pd.concat([df.drop("Gender", axis=1), encoded_df], axis=1)
'''
# Out:
# '\nfrom sklearn.preprocessing import OneHotEncoder\nimport pandas as pd\n\nencoder = OneHotEncoder(sparse_output=False)\n\nencoded = encoder.fit_transform(df[["Gender"]])\n\nencoded_df = pd.DataFrame(encoded, columns=encoder.get_feature_names_out(["Gender"]))\n\ndf = pd.concat([df.drop("Gender", axis=1), encoded_df], axis=1)\n'
