# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

dataset = pd.read_csv("../../datasets/loan_dataset.csv", encoding='latin1')

dataset.head(5)
# Out:
#   Loan_ID  Gender Married Dependend Education Self_Employment  Application  \
# 0  LP1001     NaN      No        3+  Graduate             Yes      5745.07
# 1  LP1002    Male     Yes        3+  Not Grad             Yes      7284.54
# 2  LP1003  Female     Yes         1  Not Grad              No      7368.82
# 3  LP1004     NaN     Yes         1  Not Grad             NaN      5813.84
# 4  LP1005  Female     Yes       NaN  Not Grad             NaN      5362.94
#
#    Coapplication  LoanAmount  Credit_History Property_Area Loan_status
# 0        1889.39      155.91             NaN         Rural           N
# 1        1812.68      120.63             NaN     Semiurban           Y
# 2        2613.95      111.22             0.0         Urban           Y
# 3        1629.27      111.37             0.0         Urban           Y
# 4         469.38       61.00             0.0         Rural           N

# %%
dataset.shape
# Out:
# (1050, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Loan_ID          1050 non-null   str
#  1   Gender           676 non-null    str
#  2   Married          728 non-null    str
#  3   Dependend        855 non-null    str
#  4   Education        1050 non-null   str
#  5   Self_Employment  704 non-null    str
#  6   Application      1050 non-null   float64
#  7   Coapplication    1050 non-null   float64
#  8   LoanAmount       1050 non-null   float64
#  9   Credit_History   683 non-null    float64
#  10  Property_Area    1050 non-null   str
#  11  Loan_status      1050 non-null   str
# dtypes: float64(4), str(8)
# memory usage: 98.6 KB

# %%
dataset.isnull()
# Out:
#       Loan_ID  Gender  Married  Dependend  Education  Self_Employment  \
# 0       False    True    False      False      False            False
# 1       False   False    False      False      False            False
# 2       False   False    False      False      False            False
# 3       False    True    False      False      False             True
# 4       False   False    False       True      False             True
# ...       ...     ...      ...        ...        ...              ...
# 1045    False   False     True      False      False            False
# 1046    False   False    False      False      False            False
# 1047    False    True     True      False      False            False
# 1048    False   False    False      False      False             True
# 1049    False    True    False      False      False             True
#
#       Application  Coapplication  LoanAmount  Credit_History  Property_Area  \
# 0           False          False       False            True          False
# 1           False          False       False            True          False
# 2           False          False       False           False          False
# 3           False          False       False           False          False
# 4           False          False       False           False          False
# ...           ...            ...         ...             ...            ...
# 1045        False          False       False            True          False
# 1046        False          False       False           False          False
# 1047        False          False       False           False          False
# 1048        False          False       False           False          False
# 1049        False          False       False            True          False
#
#       Loan_status
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 1045        False
# 1046        False
# 1047        False
# 1048        False
# 1049        False
#
# [1050 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender             374
# Married            322
# Dependend          195
# Education            0
# Self_Employment    346
# Application          0
# Coapplication        0
# LoanAmount           0
# Credit_History     367
# Property_Area        0
# Loan_status          0
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(1604)

# %%
dataset.shape
# Out:
# (1050, 12)

# %%
dataset.shape[0]
# Out:
# 1050

# %%
dataset.shape[1]
# Out:
# 12

# %%
dataset.notnull().sum()
# Out:
# Loan_ID            1050
# Gender              676
# Married             728
# Dependend           855
# Education          1050
# Self_Employment     704
# Application        1050
# Coapplication      1050
# LoanAmount         1050
# Credit_History      683
# Property_Area      1050
# Loan_status        1050
# dtype: int64

# %%
dataset.notnull().sum().sum()
# Out:
# np.int64(10996)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Loan_ID          1050 non-null   str
#  1   Gender           676 non-null    str
#  2   Married          728 non-null    str
#  3   Dependend        855 non-null    str
#  4   Education        1050 non-null   str
#  5   Self_Employment  704 non-null    str
#  6   Application      1050 non-null   float64
#  7   Coapplication    1050 non-null   float64
#  8   LoanAmount       1050 non-null   float64
#  9   Credit_History   683 non-null    float64
#  10  Property_Area    1050 non-null   str
#  11  Loan_status      1050 non-null   str
# dtypes: float64(4), str(8)
# memory usage: 98.6 KB

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(1604)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender             374
# Married            322
# Dependend          195
# Education            0
# Self_Employment    346
# Application          0
# Coapplication        0
# LoanAmount           0
# Credit_History     367
# Property_Area        0
# Loan_status          0
# dtype: int64

# %%
(dataset.isnull().sum() / dataset.shape[0] ) * 100
# Out:
# Loan_ID             0.000000
# Gender             35.619048
# Married            30.666667
# Dependend          18.571429
# Education           0.000000
# Self_Employment    32.952381
# Application         0.000000
# Coapplication       0.000000
# LoanAmount          0.000000
# Credit_History     34.952381
# Property_Area       0.000000
# Loan_status         0.000000
# dtype: float64

# %%
(dataset.isnull().sum().sum()/ (dataset.shape[0] * dataset.shape[1])) * 100
# Out:
# np.float64(12.730158730158731)

# %%
dataset["Gender"].mode()
# Out:
# 0    Male
# Name: Gender, dtype: str

# %%
dataset["Gender"].mode()[0]
# Out:
# 'Male'

# %%
dataset["Gender"].fillna(dataset["Gender"].mode()[0])
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 1045      Male
# 1046      Male
# 1047      Male
# 1048      Male
# 1049      Male
# Name: Gender, Length: 1050, dtype: str

# %%
dataset["Gender"].fillna(dataset["Gender"].mode()[0], inplace=True)
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\1350428233.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   dataset["Gender"].fillna(dataset["Gender"].mode()[0], inplace=True)
# 0         Male
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 1045      Male
# 1046      Male
# 1047      Male
# 1048      Male
# 1049      Male
# Name: Gender, Length: 1050, dtype: str

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Loan_ID          1050 non-null   str
#  1   Gender           676 non-null    str
#  2   Married          728 non-null    str
#  3   Dependend        855 non-null    str
#  4   Education        1050 non-null   str
#  5   Self_Employment  704 non-null    str
#  6   Application      1050 non-null   float64
#  7   Coapplication    1050 non-null   float64
#  8   LoanAmount       1050 non-null   float64
#  9   Credit_History   683 non-null    float64
#  10  Property_Area    1050 non-null   str
#  11  Loan_status      1050 non-null   str
# dtypes: float64(4), str(8)
# memory usage: 98.6 KB

# %%
dataset.select_dtypes(include="object")
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\1608443476.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   dataset.select_dtypes(include="object")
#      Loan_ID  Gender Married Dependend Education Self_Employment  \
# 0     LP1001     NaN      No        3+  Graduate             Yes
# 1     LP1002    Male     Yes        3+  Not Grad             Yes
# 2     LP1003  Female     Yes         1  Not Grad              No
# 3     LP1004     NaN     Yes         1  Not Grad             NaN
# 4     LP1005  Female     Yes       NaN  Not Grad             NaN
# ...      ...     ...     ...       ...       ...             ...
# 1045  LP2046    Male     NaN        3+  Graduate             Yes
# 1046  LP2047    Male      No         0  Not Grad              No
# 1047  LP2048     NaN     NaN         2  Graduate             Yes
# 1048  LP2049    Male     Yes         1  Graduate             NaN
# 1049  LP2050     NaN     Yes        3+  Graduate             NaN
#
#      Property_Area Loan_status
# 0            Rural           N
# 1        Semiurban           Y
# 2            Urban           Y
# 3            Urban           Y
# 4            Rural           N
# ...            ...         ...
# 1045     Semiurban           N
# 1046         Rural           N
# 1047     Semiurban           N
# 1048     Semiurban           N
# 1049         Urban           N
#
# [1050 rows x 8 columns]

# %%
dataset.select_dtypes(include="object").isnull()
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\1402889435.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   dataset.select_dtypes(include="object").isnull()
#       Loan_ID  Gender  Married  Dependend  Education  Self_Employment  \
# 0       False    True    False      False      False            False
# 1       False   False    False      False      False            False
# 2       False   False    False      False      False            False
# 3       False    True    False      False      False             True
# 4       False   False    False       True      False             True
# ...       ...     ...      ...        ...        ...              ...
# 1045    False   False     True      False      False            False
# 1046    False   False    False      False      False            False
# 1047    False    True     True      False      False            False
# 1048    False   False    False      False      False             True
# 1049    False    True    False      False      False             True
#
#       Property_Area  Loan_status
# 0             False        False
# 1             False        False
# 2             False        False
# 3             False        False
# 4             False        False
# ...             ...          ...
# 1045          False        False
# 1046          False        False
# 1047          False        False
# 1048          False        False
# 1049          False        False
#
# [1050 rows x 8 columns]

# %%
dataset.select_dtypes(include="object").isnull().sum()
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\2739403774.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   dataset.select_dtypes(include="object").isnull().sum()
# Loan_ID              0
# Gender             374
# Married            322
# Dependend          195
# Education            0
# Self_Employment    346
# Property_Area        0
# Loan_status          0
# dtype: int64

# %%
dataset.select_dtypes(include="object").isnull().columns
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\2675126635.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   dataset.select_dtypes(include="object").isnull().columns
# Index(['Loan_ID', 'Gender', 'Married', 'Dependend', 'Education',
#        'Self_Employment', 'Property_Area', 'Loan_status'],
#       dtype='str')

# %%
for i in dataset.select_dtypes(include="object").isnull().columns:
    print(i)
# Out:
# Loan_ID
# Gender
# Married
# Dependend
# Education
# Self_Employment
# Property_Area
# Loan_status
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\2408465374.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for i in dataset.select_dtypes(include="object").isnull().columns:

# %%
for i in dataset.select_dtypes(include="object").isnull().columns:
    dataset[i].fillna(dataset[i].mode()[0], inplace=True)
# Out:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\279754370.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for i in dataset.select_dtypes(include="object").isnull().columns:
# C:\Users\Tushar Nile\AppData\Local\Temp\ipykernel_16628\279754370.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   dataset[i].fillna(dataset[i].mode()[0], inplace=True)

# %%
dataset.select_dtypes(include="float64").columns
# Out:
# Index(['Application', 'Coapplication', 'LoanAmount', 'Credit_History'], dtype='str')

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")
ar = si.fit_transform(dataset[['Application', 'Coapplication', 'LoanAmount', 'Credit_History']])

# %%
ar
# Out:
# array([[5.74507000e+03, 1.88939000e+03, 1.55910000e+02, 5.00732064e-01],
#        [7.28454000e+03, 1.81268000e+03, 1.20630000e+02, 5.00732064e-01],
#        [7.36882000e+03, 2.61395000e+03, 1.11220000e+02, 0.00000000e+00],
#        ...,
#        [1.80916000e+03, 1.92072000e+03, 1.05890000e+02, 0.00000000e+00],
#        [5.64839000e+03, 2.37604000e+03, 1.01690000e+02, 1.00000000e+00],
#        [3.93174000e+03, 1.91147000e+03, 9.41300000e+01, 5.00732064e-01]],
#       shape=(1050, 4))

# %%
new_dataset = pd.DataFrame(ar, columns=dataset.select_dtypes(include="float64").columns)

# %%
new_dataset.isnull().sum()
# Out:
# Application       0
# Coapplication     0
# LoanAmount        0
# Credit_History    0
# dtype: int64

# %%
new_dataset
# Out:
#       Application  Coapplication  LoanAmount  Credit_History
# 0         5745.07        1889.39      155.91        0.500732
# 1         7284.54        1812.68      120.63        0.500732
# 2         7368.82        2613.95      111.22        0.000000
# 3         5813.84        1629.27      111.37        0.000000
# 4         5362.94         469.38       61.00        0.000000
# ...           ...            ...         ...             ...
# 1045      5664.50        2761.24       89.15        0.500732
# 1046      5710.21        1785.89      163.87        1.000000
# 1047      1809.16        1920.72      105.89        0.000000
# 1048      5648.39        2376.04      101.69        1.000000
# 1049      3931.74        1911.47       94.13        0.500732
#
# [1050 rows x 4 columns]

# %%
dataset["LoanAmount"].mean()
# Out:
# np.float64(131.7548857142857)
